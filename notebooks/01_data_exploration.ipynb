# %%
import pandas as pd

# %%
df = pd.read_csv("../data/samsung_health_sleep.csv")

# %%
df.head()
# Out:
#          date  total_sleep_time_weight  mental_recovery  wake_score  \
# 0  2025-08-20                       34             68.0           7
# 1  2025-08-21                       34             82.0           9
# 2  2025-08-21                       34              5.0          12
# 3  2025-08-22                       34             70.0           9
# 4  2025-08-23                       34             64.0           8
#
#    factor_01  factor_02  factor_03  factor_04  factor_05  factor_06  ...  \
# 0         34         34         59          0         76        533  ...
# 1         28         28         15          2         41        410  ...
# 2         11         11          0          0          0         23  ...
# 3         15         25         22          1         44        476  ...
# 4          4          4         58          0         75        598  ...
#
#    physical_recovery  movement_awakening  wake_weight  rem_score  sleep_cycle  \
# 0               76.0                36.0           12          8            2
# 1               61.0                24.0           12         20            2
# 2                8.0                 0.0           12          1            0
# 3               68.0                22.0           12         11            3
# 4               59.0                31.0           12          1            1
#
#    total_light_duration  efficiency  sleep_duration  total_sleep_time_score  \
# 0                   381        85.0             533                      31
# 1                   267        90.0             410                      25
# 2                    12       100.0              23                       2
# 3                   358        90.0             476                      33
# 4                   516        87.0             598                      32
#
#    sleep_score
# 0           72
# 1           81
# 2           43
# 3           77
# 4           58
#
# [5 rows x 31 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   date                           125 non-null    object
#  1   total_sleep_time_weight        125 non-null    int64
#  2   mental_recovery                125 non-null    float64
#  3   wake_score                     125 non-null    int64
#  4   factor_01                      125 non-null    int64
#  5   factor_02                      125 non-null    int64
#  6   factor_03                      125 non-null    int64
#  7   factor_04                      125 non-null    int64
#  8   factor_05                      125 non-null    int64
#  9   factor_06                      125 non-null    int64
#  10  factor_07                      125 non-null    int64
#  11  factor_08                      125 non-null    int64
#  12  factor_09                      125 non-null    int64
#  13  factor_10                      0 non-null      float64
#  14  deep_score                     125 non-null    int64
#  15  latency_weight                 125 non-null    int64
#  16  sleep_efficiency_with_latency  125 non-null    int64
#  17  total_rem_duration             125 non-null    int64
#  18  latency_score                  125 non-null    int64
#  19  deep_weight                    125 non-null    int64
#  20  rem_weight                     125 non-null    int64
#  21  physical_recovery              125 non-null    float64
#  22  movement_awakening             125 non-null    float64
#  23  wake_weight                    125 non-null    int64
#  24  rem_score                      125 non-null    int64
#  25  sleep_cycle                    125 non-null    int64
#  26  total_light_duration           125 non-null    int64
#  27  efficiency                     125 non-null    float64
#  28  sleep_duration                 125 non-null    int64
#  29  total_sleep_time_score         125 non-null    int64
#  30  sleep_score                    125 non-null    int64
# dtypes: float64(5), int64(25), object(1)
# memory usage: 30.4+ KB

# %%
df["date"] = pd.to_datetime(df["date"])
df = df.drop("factor_10", axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   date                           125 non-null    datetime64[ns]
#  1   total_sleep_time_weight        125 non-null    int64
#  2   mental_recovery                125 non-null    float64
#  3   wake_score                     125 non-null    int64
#  4   factor_01                      125 non-null    int64
#  5   factor_02                      125 non-null    int64
#  6   factor_03                      125 non-null    int64
#  7   factor_04                      125 non-null    int64
#  8   factor_05                      125 non-null    int64
#  9   factor_06                      125 non-null    int64
#  10  factor_07                      125 non-null    int64
#  11  factor_08                      125 non-null    int64
#  12  factor_09                      125 non-null    int64
#  13  deep_score                     125 non-null    int64
#  14  latency_weight                 125 non-null    int64
#  15  sleep_efficiency_with_latency  125 non-null    int64
#  16  total_rem_duration             125 non-null    int64
#  17  latency_score                  125 non-null    int64
#  18  deep_weight                    125 non-null    int64
#  19  rem_weight                     125 non-null    int64
#  20  physical_recovery              125 non-null    float64
#  21  movement_awakening             125 non-null    float64
#  22  wake_weight                    125 non-null    int64
#  23  rem_score                      125 non-null    int64
#  24  sleep_cycle                    125 non-null    int64
#  25  total_light_duration           125 non-null    int64
#  26  efficiency                     125 non-null    float64
#  27  sleep_duration                 125 non-null    int64
#  28  total_sleep_time_score         125 non-null    int64
#  29  sleep_score                    125 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(25)
# memory usage: 29.4 KB

# %%
df.head()
# Out:
#         date  total_sleep_time_weight  mental_recovery  wake_score  factor_01  \
# 0 2025-08-20                       34             68.0           7         34
# 1 2025-08-21                       34             82.0           9         28
# 2 2025-08-21                       34              5.0          12         11
# 3 2025-08-22                       34             70.0           9         15
# 4 2025-08-23                       34             64.0           8          4
#
#    factor_02  factor_03  factor_04  factor_05  factor_06  ...  \
# 0         34         59          0         76        533  ...
# 1         28         15          2         41        410  ...
# 2         11          0          0          0         23  ...
# 3         25         22          1         44        476  ...
# 4          4         58          0         75        598  ...
#
#    physical_recovery  movement_awakening  wake_weight  rem_score  sleep_cycle  \
# 0               76.0                36.0           12          8            2
# 1               61.0                24.0           12         20            2
# 2                8.0                 0.0           12          1            0
# 3               68.0                22.0           12         11            3
# 4               59.0                31.0           12          1            1
#
#    total_light_duration  efficiency  sleep_duration  total_sleep_time_score  \
# 0                   381        85.0             533                      31
# 1                   267        90.0             410                      25
# 2                    12       100.0              23                       2
# 3                   358        90.0             476                      33
# 4                   516        87.0             598                      32
#
#    sleep_score
# 0           72
# 1           81
# 2           43
# 3           77
# 4           58
#
# [5 rows x 30 columns]

# %%
corr = df.corr(numeric_only=True)["sleep_score"].sort_values(ascending=False)
print(corr)
# Out:
# sleep_score                      1.000000
# total_rem_duration               0.853695
# mental_recovery                  0.850922
# rem_score                        0.799854
# total_sleep_time_score           0.784489
# physical_recovery                0.653203
# sleep_duration                   0.616391
# factor_06                        0.616391
# sleep_cycle                      0.545623
# factor_04                        0.449961
# total_light_duration             0.441001
# wake_score                       0.416626
# factor_02                        0.370905
# latency_score                    0.315321
# factor_01                        0.303147
# wake_weight                      0.295806
# sleep_efficiency_with_latency    0.273408
# factor_05                        0.271509
# factor_08                        0.176490
# deep_score                       0.137632
# factor_07                        0.010640
# efficiency                      -0.052391
# factor_03                       -0.107031
# factor_09                       -0.210622
# movement_awakening              -0.276853
# rem_weight                      -0.295806
# deep_weight                     -0.295806
# total_sleep_time_weight               NaN
# latency_weight                        NaN
# Name: sleep_score, dtype: float64

# %%
df = df.drop(["total_sleep_time_weight", "factor_01", "factor_02", "factor_03", "factor_04", "factor_05", "factor_06", "factor_07", "factor_08", "factor_09", "latency_weight", "latency_score", "deep_weight", "rem_weight", "wake_weight"], axis=1)

# %%
df.head()
# Out:
#         date  mental_recovery  wake_score  deep_score  \
# 0 2025-08-20             68.0           7          10
# 1 2025-08-21             82.0           9          11
# 2 2025-08-21              5.0          12          12
# 3 2025-08-22             70.0           9           8
# 4 2025-08-23             64.0           8           1
#
#    sleep_efficiency_with_latency  total_rem_duration  physical_recovery  \
# 0                             85                  42               76.0
# 1                             90                  74               61.0
# 2                            100                   0                8.0
# 3                             90                  49               68.0
# 4                             87                   3               59.0
#
#    movement_awakening  rem_score  sleep_cycle  total_light_duration  \
# 0                36.0          8            2                   381
# 1                24.0         20            2                   267
# 2                 0.0          1            0                    12
# 3                22.0         11            3                   358
# 4                31.0          1            1                   516
#
#    efficiency  sleep_duration  total_sleep_time_score  sleep_score
# 0        85.0             533                      31           72
# 1        90.0             410                      25           81
# 2       100.0              23                       2           43
# 3        90.0             476                      33           77
# 4        87.0             598                      32           58
